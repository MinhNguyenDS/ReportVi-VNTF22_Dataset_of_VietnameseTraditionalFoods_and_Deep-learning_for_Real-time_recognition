# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab_me/YOLOv7
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_me/YOLOv7

# %%
import os
import shutil
from PIL import Image

# %%
# %cd dataset_YOLO/train_YOLO/
# Out:
# /content/drive/MyDrive/Colab_me/YOLOv7/dataset_YOLO/train_YOLO

# %%
path = 'images'
list_filename = os.listdir(path)
list_filename

# %%
for i in list_filename:
  print(i)
  a = i.split('.')
  im1 = Image.open(f'images/{i}')
  im1 = im1.convert('RGB')
  im1.save(f'images_jpg/{a[0]}.jpg')

# %%
# %cd dataset_YOLO/test_YOLO/
# Out:
# /content/drive/MyDrive/Colab_me/YOLOv7/dataset_YOLO/test_YOLO

# %%
path = 'images'
list_filename = os.listdir(path)

# %%
for i in list_filename:
  print(i)
  a = i.split('.')
  im1 = Image.open(f'images/{i}')
  im1 = im1.convert('RGB')
  im1.save(f'images_jpg/{a[0]}.jpg')
